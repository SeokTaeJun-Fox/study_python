# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])

# v1.2.6
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache
# Out:
# sk-proj-_2Lh2bEy5isJ

# %%
# 모든 llm의 response가 메모리에 저장됨
in_memory_cache = InMemoryCache()
set_llm_cache(in_memory_cache)

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
import time
from datetime import timedelta

# %%
def check_laptime(message):

    start_time = time.time()
    response = chat.invoke(message)
    end_time = time.time()

    elapsed_time = end_time - start_time
    print(f"경과 시간: {str(timedelta(seconds=elapsed_time))}")
    print(f"글자 수: {len(response.content)}")
    print(response.content)

# %%
check_laptime("피자를 만드는 방법에 대해서 알려줘!")
# Out:
# 경과 시간: 0:00:00
# 글자 수: 470
# 피자를 만드는 방법은 다음과 같습니다:
#
# 1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)
#
# 2. 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 반죽을 만든다. 반죽을 만들 때는 밀가루와 물의 비율을 적절히 조절하여 탄력 있는 반죽이 되도록 한다.
#
# 3. 반죽을 반쯤 오일이 바른 볼에 넣고 덮어 따뜻한 곳에서 발효시킨다. 약 1시간 정도가 적당하다.
#
# 4. 발효가 완료되면 반죽을 반쯤 눌러 원하는 모양으로 늘려준다. 이때 반죽이 너무 얇거나 두꺼워지지 않도록 조심해야 한다.
#
# 5. 토마토 소스를 바른 후 치즈와 토핑 재료를 올려준다.
#
# 6. 오븐을 200도로 예열한 후 피자를 넣고 15-20분간 구워준다.
#
# 7. 구워진 피자를 꺼내어 썰어서 맛있게 즐기면 된다.
#
# 이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐겨보세요!

# %%
check_laptime("피자를 만드는 방법에 대해서 알려줘")
# Out:
# 경과 시간: 0:00:05.342677
# 글자 수: 480
# 피자를 만드는 방법은 다음과 같습니다:
#
# 1. 피자 반죽을 만듭니다. 밀가루, 물, 소금, 설탕, 이스트를 섞어 부드러운 반죽을 만들어줍니다. 이후 반죽을 덮고 따뜻한 곳에서 발효시켜줍니다.
#
# 2. 발효된 반죽을 피자 팬에 넣고 손가락으로 눌러 밀어 펴줍니다. 이때 팬에 올라가는 부분은 가장 얇게 펴주고 가장자리는 두껍게 남겨줍니다.
#
# 3. 토마토 소스를 발라줍니다. 토마토 소스는 토마토 퓨레, 올리브 오일, 마늘, 소금, 후추를 섞어 만들어줍니다.
#
# 4. 치즈를 올려줍니다. 대표적으로 모짜렐라 치즈를 사용하며, 다양한 치즈를 섞어 사용해도 좋습니다.
#
# 5. 토핑을 올려줍니다. 페퍼로니, 양파, 피망, 소시지 등 다양한 토핑을 사용할 수 있습니다.
#
# 6. 200도로 예열된 오븐에서 15-20분간 구워줍니다. 피자가 노릇노릇해지고 치즈가 녹으면 완성입니다.
#
# 7. 피자를 잘라서 내놓고 싶은 소스나 피클과 함께 즐겨주세요.맛있는 피자가 완성되었습니다!

# %%
print(in_memory_cache._cache)
# Out:
# {('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918!", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]'): [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 반죽을 만든다. 반죽을 만들 때는 밀가루와 물의 비율을 적절히 조절하여 탄력 있는 반죽이 되도록 한다.\n\n3. 반죽을 반쯤 오일이 바른 볼에 넣고 덮어 따뜻한 곳에서 발효시킨다. 약 1시간 정도가 적당하다.\n\n4. 발효가 완료되면 반죽을 반쯤 눌러 원하는 모양으로 늘려준다. 이때 반죽이 너무 얇거나 두꺼워지지 않도록 조심해야 한다.\n\n5. 토마토 소스를 바른 후 치즈와 토핑 재료를 올려준다.\n\n6. 오븐을 200도로 예열한 후 피자를 넣고 15-20분간 구워준다.\n\n7. 구워진 피자를 꺼내어 썰어서 맛있게 즐기면 된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐겨보세요!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 반죽을 만든다. 반죽을 만들 때는 밀가루와 물의 비율을 적절히 조절하여 탄력 있는 반죽이 되도록 한다.\n\n3. 반죽을 반쯤 오일이 바른 볼에 넣고 덮어 따뜻한 곳에서 발효시킨다. 약 1시간 정도가 적당하다.\n\n4. 발효가 완료되면 반죽을 반쯤 눌러 원하는 모양으로 늘려준다. 이때 반죽이 너무 얇거나 두꺼워지지 않도록 조심해야 한다.\n\n5. 토마토 소스를 바른 후 치즈와 토핑 재료를 올려준다.\n\n6. 오븐을 200도로 예열한 후 피자를 넣고 15-20분간 구워준다.\n\n7. 구워진 피자를 꺼내어 썰어서 맛있게 즐기면 된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐겨보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 487, 'prompt_tokens': 28, 'total_tokens': 515, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIihVPSU8rlF8edlQB9Z7iR8OfEn', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ea-2ade-7431-8732-bb9acd765002-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 487, 'total_tokens': 515, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}, 'total_cost': 0}))], ('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]'): [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 피자 반죽을 만듭니다. 밀가루, 물, 소금, 설탕, 이스트를 섞어 부드러운 반죽을 만들어줍니다. 이후 반죽을 덮고 따뜻한 곳에서 발효시켜줍니다.\n\n2. 발효된 반죽을 피자 팬에 넣고 손가락으로 눌러 밀어 펴줍니다. 이때 팬에 올라가는 부분은 가장 얇게 펴주고 가장자리는 두껍게 남겨줍니다.\n\n3. 토마토 소스를 발라줍니다. 토마토 소스는 토마토 퓨레, 올리브 오일, 마늘, 소금, 후추를 섞어 만들어줍니다.\n\n4. 치즈를 올려줍니다. 대표적으로 모짜렐라 치즈를 사용하며, 다양한 치즈를 섞어 사용해도 좋습니다.\n\n5. 토핑을 올려줍니다. 페퍼로니, 양파, 피망, 소시지 등 다양한 토핑을 사용할 수 있습니다.\n\n6. 200도로 예열된 오븐에서 15-20분간 구워줍니다. 피자가 노릇노릇해지고 치즈가 녹으면 완성입니다.\n\n7. 피자를 잘라서 내놓고 싶은 소스나 피클과 함께 즐겨주세요.맛있는 피자가 완성되었습니다!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 피자 반죽을 만듭니다. 밀가루, 물, 소금, 설탕, 이스트를 섞어 부드러운 반죽을 만들어줍니다. 이후 반죽을 덮고 따뜻한 곳에서 발효시켜줍니다.\n\n2. 발효된 반죽을 피자 팬에 넣고 손가락으로 눌러 밀어 펴줍니다. 이때 팬에 올라가는 부분은 가장 얇게 펴주고 가장자리는 두껍게 남겨줍니다.\n\n3. 토마토 소스를 발라줍니다. 토마토 소스는 토마토 퓨레, 올리브 오일, 마늘, 소금, 후추를 섞어 만들어줍니 ...

# %%
for i in in_memory_cache._cache.keys():
    print(i)
# Out:
# ('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918!", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]')
# ('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]')

# %%
for i in in_memory_cache._cache.values():
    print(i)
# Out:
# [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 반죽을 만든다. 반죽을 만들 때는 밀가루와 물의 비율을 적절히 조절하여 탄력 있는 반죽이 되도록 한다.\n\n3. 반죽을 반쯤 오일이 바른 볼에 넣고 덮어 따뜻한 곳에서 발효시킨다. 약 1시간 정도가 적당하다.\n\n4. 발효가 완료되면 반죽을 반쯤 눌러 원하는 모양으로 늘려준다. 이때 반죽이 너무 얇거나 두꺼워지지 않도록 조심해야 한다.\n\n5. 토마토 소스를 바른 후 치즈와 토핑 재료를 올려준다.\n\n6. 오븐을 200도로 예열한 후 피자를 넣고 15-20분간 구워준다.\n\n7. 구워진 피자를 꺼내어 썰어서 맛있게 즐기면 된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐겨보세요!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 반죽을 만든다. 반죽을 만들 때는 밀가루와 물의 비율을 적절히 조절하여 탄력 있는 반죽이 되도록 한다.\n\n3. 반죽을 반쯤 오일이 바른 볼에 넣고 덮어 따뜻한 곳에서 발효시킨다. 약 1시간 정도가 적당하다.\n\n4. 발효가 완료되면 반죽을 반쯤 눌러 원하는 모양으로 늘려준다. 이때 반죽이 너무 얇거나 두꺼워지지 않도록 조심해야 한다.\n\n5. 토마토 소스를 바른 후 치즈와 토핑 재료를 올려준다.\n\n6. 오븐을 200도로 예열한 후 피자를 넣고 15-20분간 구워준다.\n\n7. 구워진 피자를 꺼내어 썰어서 맛있게 즐기면 된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐겨보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 487, 'prompt_tokens': 28, 'total_tokens': 515, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIihVPSU8rlF8edlQB9Z7iR8OfEn', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ea-2ade-7431-8732-bb9acd765002-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 487, 'total_tokens': 515, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}, 'total_cost': 0}))]
# [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 피자 반죽을 만듭니다. 밀가루, 물, 소금, 설탕, 이스트를 섞어 부드러운 반죽을 만들어줍니다. 이후 반죽을 덮고 따뜻한 곳에서 발효시켜줍니다.\n\n2. 발효된 반죽을 피자 팬에 넣고 손가락으로 눌러 밀어 펴줍니다. 이때 팬에 올라가는 부분은 가장 얇게 펴주고 가장자리는 두껍게 남겨줍니다.\n\n3. 토마토 소스를 발라줍니다. 토마토 소스는 토마토 퓨레, 올리브 오일, 마늘, 소금, 후추를 섞어 만들어줍니다.\n\n4. 치즈를 올려줍니다. 대표적으로 모짜렐라 치즈를 사용하며, 다양한 치즈를 섞어 사용해도 좋습니다.\n\n5. 토핑을 올려줍니다. 페퍼로니, 양파, 피망, 소시지 등 다양한 토핑을 사용할 수 있습니다.\n\n6. 200도로 예열된 오븐에서 15-20분간 구워줍니다. 피자가 노릇노릇해지고 치즈가 녹으면 완성입니다.\n\n7. 피자를 잘라서 내놓고 싶은 소스나 피클과 함께 즐겨주세요.맛있는 피자가 완성되었습니다!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 피자 반죽을 만듭니다. 밀가루, 물, 소금, 설탕, 이스트를 섞어 부드러운 반죽을 만들어줍니다. 이후 반죽을 덮고 따뜻한 곳에서 발효시켜줍니다.\n\n2. 발효된 반죽을 피자 팬에 넣고 손가락으로 눌러 밀어 펴줍니다. 이때 팬에 올라가는 부분은 가장 얇게 펴주고 가장자리는 두껍게 남겨줍니다.\n\n3. 토마토 소스를 발라줍니다. 토마토 소스는 토마토 퓨레, 올리브 오일, 마늘, 소금, 후추를 섞어 만들어줍니다.\n\n4. 치즈를 올려줍니다. 대표적으로 모짜렐라 치즈를 사용하며, 다양한 치즈를 섞어 사용해도 좋습니다.\n\n5. 토핑을 올려줍니다. 페퍼로니, 양파, 피망, 소시지 등 다양한 토핑을 사용할 수 있습니다.\n\n6. 200도로 예열된 오븐에서 15-20분간 구워줍니다. 피자가 노릇노릇해지고 치즈가 녹으면 완성입니다.\n\n7. 피자를 잘라서 내놓고 싶은 소스나 피클과 함께 즐겨주세요.맛있는 피자가 완성되었습니다!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 498, 'prompt_tokens': 27, 'total_tokens': 525, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIj16zpka5royNjXK8lGxbCTKqKI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ea-7b54-7130-982f-f8beff6665c9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 498, 'total_tokens': 525, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))]

# %%
# 프로그램 종료 시 삭제 자동 삭제
# 캐시 삭제
in_memory_cache.clear()

# %%
in_memory_cache._cache
# Out:
# {}

# %% [markdown]
# # 디버그 설정

# %%
from langchain_core.globals import set_debug

# %%
set_debug(True)

# %%
chat.invoke("랍스터는 누구의 후손이니?")
# Out:
# [llm/start] [llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: 랍스터는 누구의 후손이니?"
#   ]
# }
# [llm/end] [llm:ChatOpenAI] [1.72s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "랍스터는 게의 후손입니다.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "랍스터는 게의 후손입니다.",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 12,
#                 "prompt_tokens": 23,
#                 "total_tokens": 35,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-3.5-turbo-0125",
#               "system_fingerprint": null,
#               "id": "chatcmpl-DfIoiVxWA0w2IO1LONZNyFHA1CEo0",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019e24ef-d996-7240-94ca-a1d652248ba8-0",
#             "usage_metadata": {
#               "input_tokens": 23,
#               "output_tokens": 12,
#               "total_tokens": 35,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 12,
#       "prompt_tokens": 23,
#       "total_tokens": 35,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-3.5-turbo-0125",
#     "system_fingerprint": null,
#     "id": "chatcmpl-DfIoiVxWA0w2IO1LONZNyFHA1CEo0",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# AIMessage(content='랍스터는 게의 후손입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 23, 'total_tokens': 35, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIoiVxWA0w2IO1LONZNyFHA1CEo0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ef-d996-7240-94ca-a1d652248ba8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 12, 'total_tokens': 35, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
set_debug(False)

# %%
set_llm_cache(None)
